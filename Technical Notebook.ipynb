# %% [markdown]
# # 1. Import libraries

# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # 2. Load data

# %% [markdown]
# ## The following 3 csv's will be analyzed:
# - tn.movie_budgets.csv.gz
# - tmdb.movies.csv.gz
# - imdb.title.basics.csv.gz

# %% [markdown]
# ### A. tn.movie_budgets.csv.gz
# - Referred to as 'budget_gross_df'

# %%
budget_gross_df = pd.read_csv('zippedData/tn.movie_budgets.csv.gz', compression='gzip')

# %%
budget_gross_df.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
budget_gross_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %% [markdown]
# ### B. tmdb.movies.csv.gz
# - Referred to as 'rating_df'

# %%
rating_df = pd.read_csv('zippedData/tmdb.movies.csv.gz', compression='gzip')

# %%
rating_df.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186

# %%
rating_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26517 entries, 0 to 26516
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         26517 non-null  int64
#  1   genre_ids          26517 non-null  object
#  2   id                 26517 non-null  int64
#  3   original_language  26517 non-null  object
#  4   original_title     26517 non-null  object
#  5   popularity         26517 non-null  float64
#  6   release_date       26517 non-null  object
#  7   title              26517 non-null  object
#  8   vote_average       26517 non-null  float64
#  9   vote_count         26517 non-null  int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# ### C. imdb.title.basics.csv.gz
# - Referred to as 'runtime_genre_df'

# %%
runtime_genre_df = pd.read_csv('zippedData/imdb.title.basics.csv.gz', compression='gzip')

# %%
runtime_genre_df.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
runtime_genre_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %% [markdown]
# # 3. Data Cleaning

# %% [markdown]
# ### A. budget_gross_df

# %%
budget_gross_df.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %% [markdown]
# #### Action items
# - Remove id column
# - Update release date to YYYY-MM-DD format
# - Lowercase movie for case consistency
# - Rename movie to title
# - Remove '$' & ',' in production_budget, domestic_gross, worldwide_gross
# - Convert from str to int for production_budget, domestic_gross, worldwide_gross

# %%
#Update release_date to datetime format
budget_gross_df['release_date'] = pd.to_datetime(budget_gross_df['release_date'], infer_datetime_format=True)
budget_gross_df.head()
# Out:
#    id release_date                                        movie  \
# 0   1   2009-12-18                                       Avatar
# 1   2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2   3   2019-06-07                                 Dark Phoenix
# 3   4   2015-05-01                      Avengers: Age of Ultron
# 4   5   2017-12-15            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
#Lowercase movie
budget_gross_df['movie'] = budget_gross_df['movie'].str.lower()
budget_gross_df.head()
# Out:
#    id release_date                                        movie  \
# 0   1   2009-12-18                                       avatar
# 1   2   2011-05-20  pirates of the caribbean: on stranger tides
# 2   3   2019-06-07                                 dark phoenix
# 3   4   2015-05-01                      avengers: age of ultron
# 4   5   2017-12-15            star wars ep. viii: the last jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
#Remove'$' from production_budget
budget_gross_df['production_budget'] = budget_gross_df['production_budget'].str.replace('$', '')
budget_gross_df.head()
# Out:
#    id release_date                                        movie  \
# 0   1   2009-12-18                                       avatar
# 1   2   2011-05-20  pirates of the caribbean: on stranger tides
# 2   3   2019-06-07                                 dark phoenix
# 3   4   2015-05-01                      avengers: age of ultron
# 4   5   2017-12-15            star wars ep. viii: the last jedi
#
#   production_budget domestic_gross worldwide_gross
# 0       425,000,000   $760,507,625  $2,776,345,279
# 1       410,600,000   $241,063,875  $1,045,663,875
# 2       350,000,000    $42,762,350    $149,762,350
# 3       330,600,000   $459,005,868  $1,403,013,963
# 4       317,000,000   $620,181,382  $1,316,721,747

# %%
#Remove ',' from production_budget
budget_gross_df['production_budget'] = budget_gross_df['production_budget'].str.replace(',', '')
budget_gross_df.head()
# Out:
#    id release_date                                        movie  \
# 0   1   2009-12-18                                       avatar
# 1   2   2011-05-20  pirates of the caribbean: on stranger tides
# 2   3   2019-06-07                                 dark phoenix
# 3   4   2015-05-01                      avengers: age of ultron
# 4   5   2017-12-15            star wars ep. viii: the last jedi
#
#   production_budget domestic_gross worldwide_gross
# 0         425000000   $760,507,625  $2,776,345,279
# 1         410600000   $241,063,875  $1,045,663,875
# 2         350000000    $42,762,350    $149,762,350
# 3         330600000   $459,005,868  $1,403,013,963
# 4         317000000   $620,181,382  $1,316,721,747

# %%
#Convert production_budget from str to int
budget_gross_df['production_budget'] = budget_gross_df['production_budget'].astype(int)
budget_gross_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   datetime64[ns]
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   int64
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: datetime64[ns](1), int64(2), object(3)
# memory usage: 271.2+ KB

# %%
#Remove'$' from domestic_gross
budget_gross_df['domestic_gross'] = budget_gross_df['domestic_gross'].str.replace('$', '')
budget_gross_df.head()
# Out:
#    id release_date                                        movie  \
# 0   1   2009-12-18                                       avatar
# 1   2   2011-05-20  pirates of the caribbean: on stranger tides
# 2   3   2019-06-07                                 dark phoenix
# 3   4   2015-05-01                      avengers: age of ultron
# 4   5   2017-12-15            star wars ep. viii: the last jedi
#
#    production_budget domestic_gross worldwide_gross
# 0          425000000    760,507,625  $2,776,345,279
# 1          410600000    241,063,875  $1,045,663,875
# 2          350000000     42,762,350    $149,762,350
# 3          330600000    459,005,868  $1,403,013,963
# 4          317000000    620,181,382  $1,316,721,747

# %%
#Remove ',' from domestic_gross
budget_gross_df['domestic_gross'] = budget_gross_df['domestic_gross'].str.replace(',', '')
budget_gross_df.head()
# Out:
#    id release_date                                        movie  \
# 0   1   2009-12-18                                       avatar
# 1   2   2011-05-20  pirates of the caribbean: on stranger tides
# 2   3   2019-06-07                                 dark phoenix
# 3   4   2015-05-01                      avengers: age of ultron
# 4   5   2017-12-15            star wars ep. viii: the last jedi
#
#    production_budget domestic_gross worldwide_gross
# 0          425000000      760507625  $2,776,345,279
# 1          410600000      241063875  $1,045,663,875
# 2          350000000       42762350    $149,762,350
# 3          330600000      459005868  $1,403,013,963
# 4          317000000      620181382  $1,316,721,747

# %%
#Convert domestic_gross from str to int
budget_gross_df['domestic_gross'] = budget_gross_df['domestic_gross'].astype(int)
budget_gross_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   datetime64[ns]
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   int64
#  4   domestic_gross     5782 non-null   int64
#  5   worldwide_gross    5782 non-null   object
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 271.2+ KB

# %%
#Remove'$' from worldwide_gross
budget_gross_df['worldwide_gross'] = budget_gross_df['worldwide_gross'].str.replace('$', '')
budget_gross_df.head()
# Out:
#    id release_date                                        movie  \
# 0   1   2009-12-18                                       avatar
# 1   2   2011-05-20  pirates of the caribbean: on stranger tides
# 2   3   2019-06-07                                 dark phoenix
# 3   4   2015-05-01                      avengers: age of ultron
# 4   5   2017-12-15            star wars ep. viii: the last jedi
#
#    production_budget  domestic_gross worldwide_gross
# 0          425000000       760507625   2,776,345,279
# 1          410600000       241063875   1,045,663,875
# 2          350000000        42762350     149,762,350
# 3          330600000       459005868   1,403,013,963
# 4          317000000       620181382   1,316,721,747

# %%
#Remove ',' from worldwide_gross
budget_gross_df['worldwide_gross'] = budget_gross_df['worldwide_gross'].str.replace(',', '')
budget_gross_df.head()
# Out:
#    id release_date                                        movie  \
# 0   1   2009-12-18                                       avatar
# 1   2   2011-05-20  pirates of the caribbean: on stranger tides
# 2   3   2019-06-07                                 dark phoenix
# 3   4   2015-05-01                      avengers: age of ultron
# 4   5   2017-12-15            star wars ep. viii: the last jedi
#
#    production_budget  domestic_gross worldwide_gross
# 0          425000000       760507625      2776345279
# 1          410600000       241063875      1045663875
# 2          350000000        42762350       149762350
# 3          330600000       459005868      1403013963
# 4          317000000       620181382      1316721747

# %%
#Convert worldwide_gross from str to int
budget_gross_df['worldwide_gross'] = budget_gross_df['worldwide_gross'].astype(int)
budget_gross_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   datetime64[ns]
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   int64
#  4   domestic_gross     5782 non-null   int64
#  5   worldwide_gross    5782 non-null   int64
# dtypes: datetime64[ns](1), int64(4), object(1)
# memory usage: 271.2+ KB

# %%
#Rename movie to title
budget_gross_df = budget_gross_df.rename(columns = {'movie': 'title'})
budget_gross_df.head()
# Out:
#    id release_date                                        title  \
# 0   1   2009-12-18                                       avatar
# 1   2   2011-05-20  pirates of the caribbean: on stranger tides
# 2   3   2019-06-07                                 dark phoenix
# 3   4   2015-05-01                      avengers: age of ultron
# 4   5   2017-12-15            star wars ep. viii: the last jedi
#
#    production_budget  domestic_gross  worldwide_gross
# 0          425000000       760507625       2776345279
# 1          410600000       241063875       1045663875
# 2          350000000        42762350        149762350
# 3          330600000       459005868       1403013963
# 4          317000000       620181382       1316721747

# %%
# Remove column id
budget_gross_df = budget_gross_df.drop('id', axis=1)
budget_gross_df.head()
# Out:
#   release_date                                        title  \
# 0   2009-12-18                                       avatar
# 1   2011-05-20  pirates of the caribbean: on stranger tides
# 2   2019-06-07                                 dark phoenix
# 3   2015-05-01                      avengers: age of ultron
# 4   2017-12-15            star wars ep. viii: the last jedi
#
#    production_budget  domestic_gross  worldwide_gross
# 0          425000000       760507625       2776345279
# 1          410600000       241063875       1045663875
# 2          350000000        42762350        149762350
# 3          330600000       459005868       1403013963
# 4          317000000       620181382       1316721747

# %% [markdown]
# ### B. rating

# %%
rating_df.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186

# %%
rating_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26517 entries, 0 to 26516
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         26517 non-null  int64
#  1   genre_ids          26517 non-null  object
#  2   id                 26517 non-null  int64
#  3   original_language  26517 non-null  object
#  4   original_title     26517 non-null  object
#  5   popularity         26517 non-null  float64
#  6   release_date       26517 non-null  object
#  7   title              26517 non-null  object
#  8   vote_average       26517 non-null  float64
#  9   vote_count         26517 non-null  int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# #### Action items:

# %% [markdown]
# - Delete columns 'Unnamed: 0', 'genre_ids', 'id', 'original_title', 'release_date' (since budget_gross already has it)
# - Lowercase title
# - Change vote_average from str to float

# %%
#Delete unnecessary columns
rating_df = rating_df.drop(['Unnamed: 0', 'genre_ids', 'id', 'original_title', 'release_date'],axis=1)
rating_df.head()
# Out:
#   original_language  popularity                                         title  \
# 0                en      33.533  Harry Potter and the Deathly Hallows: Part 1
# 1                en      28.734                      How to Train Your Dragon
# 2                en      28.515                                    Iron Man 2
# 3                en      28.005                                     Toy Story
# 4                en      27.920                                     Inception
#
#    vote_average  vote_count
# 0           7.7       10788
# 1           7.7        7610
# 2           6.8       12368
# 3           7.9       10174
# 4           8.3       22186

# %%
#Lowercase title
rating_df['title'] = rating_df['title'].str.lower()
rating_df.head()
# Out:
#   original_language  popularity                                         title  \
# 0                en      33.533  harry potter and the deathly hallows: part 1
# 1                en      28.734                      how to train your dragon
# 2                en      28.515                                    iron man 2
# 3                en      28.005                                     toy story
# 4                en      27.920                                     inception
#
#    vote_average  vote_count
# 0           7.7       10788
# 1           7.7        7610
# 2           6.8       12368
# 3           7.9       10174
# 4           8.3       22186

# %%
#Change vote_average to float
rating_df['vote_average'] = rating_df['vote_average'].astype(float)
rating_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26517 entries, 0 to 26516
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   original_language  26517 non-null  object
#  1   popularity         26517 non-null  float64
#  2   title              26517 non-null  object
#  3   vote_average       26517 non-null  float64
#  4   vote_count         26517 non-null  int64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 1.0+ MB

# %% [markdown]
# ### C. runtime_genre

# %%
runtime_genre_df.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %% [markdown]
# #### Action items

# %% [markdown]
# - Remove columns: 'tconst', 'original title', 'start_year'
# - Lowercase primary_title
# - Lowercase genres
# - Change primary_title to title

# %%
# drop columns
runtime_genre_df = runtime_genre_df.drop(['tconst', 'original_title', 'start_year'], axis=1)
runtime_genre_df.head()
# Out:
#                      primary_title  runtime_minutes                genres
# 0                        Sunghursh            175.0    Action,Crime,Drama
# 1  One Day Before the Rainy Season            114.0       Biography,Drama
# 2       The Other Side of the Wind            122.0                 Drama
# 3                  Sabse Bada Sukh              NaN          Comedy,Drama
# 4         The Wandering Soap Opera             80.0  Comedy,Drama,Fantasy

# %%
# lowercase primary_title
runtime_genre_df['primary_title'] = runtime_genre_df['primary_title'].str.lower()
runtime_genre_df.head()
# Out:
#                      primary_title  runtime_minutes                genres
# 0                        sunghursh            175.0    Action,Crime,Drama
# 1  one day before the rainy season            114.0       Biography,Drama
# 2       the other side of the wind            122.0                 Drama
# 3                  sabse bada sukh              NaN          Comedy,Drama
# 4         the wandering soap opera             80.0  Comedy,Drama,Fantasy

# %%
# lowercase genres
runtime_genre_df['genres'] = runtime_genre_df['genres'].str.lower()
runtime_genre_df.head()
# Out:
#                      primary_title  runtime_minutes                genres
# 0                        sunghursh            175.0    action,crime,drama
# 1  one day before the rainy season            114.0       biography,drama
# 2       the other side of the wind            122.0                 drama
# 3                  sabse bada sukh              NaN          comedy,drama
# 4         the wandering soap opera             80.0  comedy,drama,fantasy

# %%
# change column name primary_title to title
runtime_genre_df = runtime_genre_df.rename(columns = {'primary_title': 'title'})
runtime_genre_df.head()
# Out:
#                              title  runtime_minutes                genres
# 0                        sunghursh            175.0    action,crime,drama
# 1  one day before the rainy season            114.0       biography,drama
# 2       the other side of the wind            122.0                 drama
# 3                  sabse bada sukh              NaN          comedy,drama
# 4         the wandering soap opera             80.0  comedy,drama,fantasy

# %% [markdown]
# # 4. Merge 3 dataframes into 1 using inner join
# - budget_gross_df
# - rating_df
# - runtime_genre_df
#
# Note: Merged dataframe is referred to as final_df

# %%
budget_gross_df.head()
# Out:
#   release_date                                        title  \
# 0   2009-12-18                                       avatar
# 1   2011-05-20  pirates of the caribbean: on stranger tides
# 2   2019-06-07                                 dark phoenix
# 3   2015-05-01                      avengers: age of ultron
# 4   2017-12-15            star wars ep. viii: the last jedi
#
#    production_budget  domestic_gross  worldwide_gross
# 0          425000000       760507625       2776345279
# 1          410600000       241063875       1045663875
# 2          350000000        42762350        149762350
# 3          330600000       459005868       1403013963
# 4          317000000       620181382       1316721747

# %%
budget_gross_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   release_date       5782 non-null   datetime64[ns]
#  1   title              5782 non-null   object
#  2   production_budget  5782 non-null   int64
#  3   domestic_gross     5782 non-null   int64
#  4   worldwide_gross    5782 non-null   int64
# dtypes: datetime64[ns](1), int64(3), object(1)
# memory usage: 226.0+ KB

# %%
rating_df.head()
# Out:
#   original_language  popularity                                         title  \
# 0                en      33.533  harry potter and the deathly hallows: part 1
# 1                en      28.734                      how to train your dragon
# 2                en      28.515                                    iron man 2
# 3                en      28.005                                     toy story
# 4                en      27.920                                     inception
#
#    vote_average  vote_count
# 0           7.7       10788
# 1           7.7        7610
# 2           6.8       12368
# 3           7.9       10174
# 4           8.3       22186

# %%
rating_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26517 entries, 0 to 26516
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   original_language  26517 non-null  object
#  1   popularity         26517 non-null  float64
#  2   title              26517 non-null  object
#  3   vote_average       26517 non-null  float64
#  4   vote_count         26517 non-null  int64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 1.0+ MB

# %%
runtime_genre_df.head()
# Out:
#                              title  runtime_minutes                genres
# 0                        sunghursh            175.0    action,crime,drama
# 1  one day before the rainy season            114.0       biography,drama
# 2       the other side of the wind            122.0                 drama
# 3                  sabse bada sukh              NaN          comedy,drama
# 4         the wandering soap opera             80.0  comedy,drama,fantasy

# %%
runtime_genre_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 3 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   title            146144 non-null  object
#  1   runtime_minutes  114405 non-null  float64
#  2   genres           140736 non-null  object
# dtypes: float64(1), object(2)
# memory usage: 3.3+ MB

# %%
#Merge inner on title
final_df = budget_gross_df.merge(rating_df, on='title').merge(runtime_genre_df, on='title')
final_df.head()
# Out:
#   release_date                                        title  \
# 0   2009-12-18                                       avatar
# 1   2011-05-20  pirates of the caribbean: on stranger tides
# 2   2015-05-01                      avengers: age of ultron
# 3   2018-04-27                       avengers: infinity war
# 4   2017-11-17                               justice league
#
#    production_budget  domestic_gross  worldwide_gross original_language  \
# 0          425000000       760507625       2776345279                en
# 1          410600000       241063875       1045663875                en
# 2          330600000       459005868       1403013963                en
# 3          300000000       678815482       2048134200                en
# 4          300000000       229024295        655945209                en
#
#    popularity  vote_average  vote_count  runtime_minutes  \
# 0      26.526           7.4       18676             93.0
# 1      30.579           6.4        8571            136.0
# 2      44.383           7.3       13457            141.0
# 3      80.773           8.3       13948            149.0
# 4      34.953           6.2        7510            120.0
#
#                      genres
# 0                    horror
# 1  action,adventure,fantasy
# 2   action,adventure,sci-fi
# 3   action,adventure,sci-fi
# 4  action,adventure,fantasy

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4715 entries, 0 to 4714
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   release_date       4715 non-null   datetime64[ns]
#  1   title              4715 non-null   object
#  2   production_budget  4715 non-null   int64
#  3   domestic_gross     4715 non-null   int64
#  4   worldwide_gross    4715 non-null   int64
#  5   original_language  4715 non-null   object
#  6   popularity         4715 non-null   float64
#  7   vote_average       4715 non-null   float64
#  8   vote_count         4715 non-null   int64
#  9   runtime_minutes    4235 non-null   float64
#  10  genres             4639 non-null   object
# dtypes: datetime64[ns](1), float64(3), int64(4), object(3)
# memory usage: 442.0+ KB

# %% [markdown]
# # 5. Data cleaning on merged dataframe

# %%
#Number of NaN values by column
final_df.isna().sum()
# Out:
# release_date           0
# title                  0
# production_budget      0
# domestic_gross         0
# worldwide_gross        0
# original_language      0
# popularity             0
# vote_average           0
# vote_count             0
# runtime_minutes      480
# genres                76
# dtype: int64

# %%
#Drop NaN
final_df.dropna(inplace=True)

# %%
#Double check for NaN
final_df.isna().sum()
# Out:
# release_date         0
# title                0
# production_budget    0
# domestic_gross       0
# worldwide_gross      0
# original_language    0
# popularity           0
# vote_average         0
# vote_count           0
# runtime_minutes      0
# genres               0
# dtype: int64

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4217 entries, 0 to 4714
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   release_date       4217 non-null   datetime64[ns]
#  1   title              4217 non-null   object
#  2   production_budget  4217 non-null   int64
#  3   domestic_gross     4217 non-null   int64
#  4   worldwide_gross    4217 non-null   int64
#  5   original_language  4217 non-null   object
#  6   popularity         4217 non-null   float64
#  7   vote_average       4217 non-null   float64
#  8   vote_count         4217 non-null   int64
#  9   runtime_minutes    4217 non-null   float64
#  10  genres             4217 non-null   object
# dtypes: datetime64[ns](1), float64(3), int64(4), object(3)
# memory usage: 395.3+ KB

# %%
final_df.head()
# Out:
#   release_date                                        title  \
# 0   2009-12-18                                       avatar
# 1   2011-05-20  pirates of the caribbean: on stranger tides
# 2   2015-05-01                      avengers: age of ultron
# 3   2018-04-27                       avengers: infinity war
# 4   2017-11-17                               justice league
#
#    production_budget  domestic_gross  worldwide_gross original_language  \
# 0          425000000       760507625       2776345279                en
# 1          410600000       241063875       1045663875                en
# 2          330600000       459005868       1403013963                en
# 3          300000000       678815482       2048134200                en
# 4          300000000       229024295        655945209                en
#
#    popularity  vote_average  vote_count  runtime_minutes  \
# 0      26.526           7.4       18676             93.0
# 1      30.579           6.4        8571            136.0
# 2      44.383           7.3       13457            141.0
# 3      80.773           8.3       13948            149.0
# 4      34.953           6.2        7510            120.0
#
#                      genres
# 0                    horror
# 1  action,adventure,fantasy
# 2   action,adventure,sci-fi
# 3   action,adventure,sci-fi
# 4  action,adventure,fantasy

# %%
#Combining multiple genres as cross-genre as it will be diffult to perform analysis on movies with multiple genres
final_df.loc[final_df['genres'].str.contains(','), 'genres'] = 'cross-genre'
final_df.head()
# Out:
#   release_date                                        title  \
# 0   2009-12-18                                       avatar
# 1   2011-05-20  pirates of the caribbean: on stranger tides
# 2   2015-05-01                      avengers: age of ultron
# 3   2018-04-27                       avengers: infinity war
# 4   2017-11-17                               justice league
#
#    production_budget  domestic_gross  worldwide_gross original_language  \
# 0          425000000       760507625       2776345279                en
# 1          410600000       241063875       1045663875                en
# 2          330600000       459005868       1403013963                en
# 3          300000000       678815482       2048134200                en
# 4          300000000       229024295        655945209                en
#
#    popularity  vote_average  vote_count  runtime_minutes       genres
# 0      26.526           7.4       18676             93.0       horror
# 1      30.579           6.4        8571            136.0  cross-genre
# 2      44.383           7.3       13457            141.0  cross-genre
# 3      80.773           8.3       13948            149.0  cross-genre
# 4      34.953           6.2        7510            120.0  cross-genre

# %%
#Sort ascending title
final_df = final_df.sort_values(by='title', ascending=True)
final_df.head()
# Out:
#      release_date                  title  production_budget  domestic_gross  \
# 4312   2015-11-20                #horror            1500000               0
# 3611   2016-03-11    10 cloverfield lane            5000000        72082999
# 3004   2015-11-11  10 days in a madhouse           12000000           14616
# 1761   2018-01-19              12 strong           35000000        45819713
# 2433   2013-10-18       12 years a slave           20000000        56671993
#
#       worldwide_gross original_language  popularity  vote_average  vote_count  \
# 4312                0                de       6.099           3.3         102
# 3611        108286422                en      17.892           6.9        4629
# 3004            14616                en       0.955           5.4           7
# 1761         71118378                en      13.183           5.6        1312
# 2433        181025343                en      16.493           7.9        6631
#
#       runtime_minutes       genres
# 4312            101.0  cross-genre
# 3611            103.0  cross-genre
# 3004            111.0        drama
# 1761            130.0  cross-genre
# 2433            134.0  cross-genre

# %%
#Sum of duplicate rows
final_df.duplicated().sum()
# Out:
# 287

# %%
#Find duplicate rows based on release_date and title
duplicate_df = final_df[final_df.duplicated(['release_date', 'title'])] 
duplicate_df
# Out:
#      release_date  title  production_budget  domestic_gross  worldwide_gross  \
# 4432   2016-03-01   1982            1000000               0                0
# 3435   2011-09-16      3            7200000           59774           295492
# 3436   2011-09-16      3            7200000           59774           295492
# 3437   2011-09-16      3            7200000           59774           295492
# 3438   2011-09-16      3            7200000           59774           295492
# ...           ...    ...                ...             ...              ...
# 2894   2015-12-04  youth           13000000         2703296         24001573
# 2904   2015-12-04  youth           13000000         2703296         24001573
# 2903   2015-12-04  youth           13000000         2703296         24001573
# 2902   2015-12-04  youth           13000000         2703296         24001573
# 1823   2006-08-11   zoom           35000000        11989328         12506188
#
#      original_language  popularity  vote_average  vote_count  runtime_minutes  \
# 4432                en       0.600           7.5           2             90.0
# 3435                en       1.816           6.0           2            145.0
# 3436                en       1.816           6.0           2            115.0
# 3437                en       1.816           6.0           2             80.0
# 3438                en       1.816           6.0           2             57.0
# ...                ...         ...           ...         ...              ...
# 2894                he       1.008           5.3           9            135.0
# 2904                zh       5.082           7.7          27            135.0
# 2903                zh       5.082           7.7          27            124.0
# 2902                zh       5.082           7.7          27            124.0
# 1823                en       3.434           5.5          43             96.0
#
#            genres
# 4432        drama
# 3435  cross-genre
# 3436  cross-genre
# 3437  cross-genre
# 3438        drama
# ...           ...
# 2894  cross-genre
# 2904  cross-genre
# 2903        drama
# 2902  cross-genre
# 1823  cross-genre
#
# [2338 rows x 11 columns]

# %%
#Keep first instance and drop duplicates
final_df = final_df.drop_duplicates(['release_date','title'], keep = 'first')

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1879 entries, 4312 to 216
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   release_date       1879 non-null   datetime64[ns]
#  1   title              1879 non-null   object
#  2   production_budget  1879 non-null   int64
#  3   domestic_gross     1879 non-null   int64
#  4   worldwide_gross    1879 non-null   int64
#  5   original_language  1879 non-null   object
#  6   popularity         1879 non-null   float64
#  7   vote_average       1879 non-null   float64
#  8   vote_count         1879 non-null   int64
#  9   runtime_minutes    1879 non-null   float64
#  10  genres             1879 non-null   object
# dtypes: datetime64[ns](1), float64(3), int64(4), object(3)
# memory usage: 176.2+ KB

# %%
final_df.tail()
# Out:
#      release_date        title  production_budget  domestic_gross  \
# 3766   2015-08-28       zipper            4500000               0
# 1099   2011-07-08    zookeeper           80000000        80360866
# 1435   2016-02-12  zoolander 2           50000000        28848693
# 1824   2006-08-11         zoom           35000000        11989328
# 216    2016-03-04     zootopia          150000000       341268248
#
#       worldwide_gross original_language  popularity  vote_average  vote_count  \
# 3766                0                en       9.373           5.7          85
# 1099        170805525                en      10.764           5.3         886
# 1435         55348693                en      12.997           4.7        1374
# 1824         12506188                en       3.434           5.5          43
# 216        1019429616                en      27.549           7.7        9977
#
#       runtime_minutes       genres
# 3766            112.0  cross-genre
# 1099            102.0  cross-genre
# 1435            101.0       comedy
# 1824            158.0  cross-genre
# 216             108.0  cross-genre

# %%
#Double check sum of duplicate rows
final_df.duplicated().sum()
# Out:
# 0

# %%
#Double check duplicate rows based on title and release date
final_df.duplicated(['title', 'release_date']).sum()
# Out:
# 0

# %%
#Check for duplicate rows based on title
final_df.duplicated('title').sum()
# Out:
# 52

# %%
#Display duplicate rows based on title
title_test_df = final_df[final_df.duplicated('title', keep = False)]
title_test_df
# Out:
#      release_date                      title  production_budget  \
# 1752   2010-04-30  a nightmare on elm street           35000000
# 1753   1984-11-09  a nightmare on elm street            1800000
# 74     1951-07-28        alice in wonderland            3000000
# 72     2010-03-05        alice in wonderland          200000000
# 187    1991-11-13       beauty and the beast           20000000
# ...           ...                        ...                ...
# 2627   1996-02-23              unforgettable           18000000
# 1605   2011-02-18                    unknown           40000000
# 1609   2006-11-03                    unknown            3700000
# 897    2018-10-05                      venom          116000000
# 902    2005-09-16                      venom           25000000
#
#       domestic_gross  worldwide_gross original_language  popularity  \
# 1752        63075011        117729621                en       9.795
# 1753        25504513         25504513                en       9.795
# 74                 0                0                en      22.020
# 72         334191110       1025491110                en       0.600
# 187        376057266        608431132                en      31.793
# ...              ...              ...               ...         ...
# 2627         2483790          2483790                en       8.323
# 1605        63686397        136123083                en      12.080
# 1609           26403          3355048                en      12.080
# 897        213511408        853628605                en      44.007
# 902           881745           881745                en      44.007
#
#       vote_average  vote_count  runtime_minutes       genres
# 1752           5.5        1408             95.0  cross-genre
# 1753           5.5        1408             95.0  cross-genre
# 74             6.6        8713             48.0  documentary
# 72             6.0           1             99.0  cross-genre
# 187            6.9       11023            112.0  cross-genre
# ...            ...         ...              ...          ...
# 2627           5.5         310            130.0  cross-genre
# 1605           6.6        2043            113.0  cross-genre
# 1609           6.6        2043            113.0  cross-genre
# 897            6.6        6206            112.0  cross-genre
# 902            6.6        6206             92.0     thriller
#
# [102 rows x 11 columns]

# %%
#Display all duplicate rows based on title
print(title_test_df[['title', 'release_date']].to_string())
# Out:
#                              title release_date
# 1752     a nightmare on elm street   2010-04-30
# 1753     a nightmare on elm street   1984-11-09
# 74             alice in wonderland   1951-07-28
# 72             alice in wonderland   2010-03-05
# 187           beauty and the beast   1991-11-13
# 173           beauty and the beast   2017-03-17
# 1007                       ben-hur   1959-11-18
# 1006                       ben-hur   2016-08-19
# 2106                      brothers   2009-12-04
# 2139                      brothers   2015-08-14
# 2864                          ca$h   2010-03-26
# 2863                          ca$h   2008-12-31
# 1958                        carrie   2013-10-18
# 1960                        carrie   1976-11-16
# 963                     cinderella   2015-03-13
# 984                     cinderella   1950-02-15
# 869            clash of the titans   2010-04-01
# 870            clash of the titans   1981-06-12
# 1031           conan the barbarian   2011-08-19
# 1032           conan the barbarian   1982-05-14
# 2953                    crossroads   2015-06-23
# 2949                    crossroads   2002-02-15
# 2325            dangerous liaisons   1988-12-21
# 2324            dangerous liaisons   2012-11-09
# 2408            death at a funeral   2010-04-16
# 2409            death at a funeral   2007-08-17
# 893                 fantastic four   2005-07-08
# 892                 fantastic four   2015-08-07
# 2085                    flatliners   1990-08-10
# 2086                    flatliners   2017-09-29
# 2332                     footloose   1984-02-17
# 2331                     footloose   2011-10-14
# 240                   ghostbusters   2016-07-15
# 241                   ghostbusters   1984-06-08
# 194                       godzilla   2014-05-16
# 195                       godzilla   1998-05-19
# 2739                     halloween   1978-10-17
# 2737                     halloween   2007-08-31
# 2738                     halloween   2018-10-19
# 1796                         heist   2001-11-09
# 1803                         heist   2015-11-13
# 938                       hercules   1997-06-13
# 936                       hercules   2014-07-25
# 516                           home   2009-06-05
# 293                           home   2015-03-27
# 756                           home   2009-04-23
# 2576                   left behind   2014-10-03
# 2571                   left behind   2001-02-02
# 2230                        legend   1986-04-18
# 2255                        legend   2015-11-20
# 1135                          life   1999-04-16
# 1141                          life   2017-03-24
# 3778      night of the living dead   1968-10-01
# 3777      night of the living dead   1990-10-19
# 945                    point break   2015-12-25
# 946                    point break   1991-07-12
# 1759                   poltergeist   1982-06-04
# 1758                   poltergeist   2015-05-22
# 44                      robin hood   2018-11-21
# 43                      robin hood   2010-05-14
# 890                        robocop   2014-02-12
# 891                        robocop   1987-07-17
# 1967                  side effects   2005-09-09
# 1965                  side effects   2013-02-08
# 2747                        snitch   2012-12-31
# 2744                        snitch   2013-02-22
# 866   teenage mutant ninja turtles   1990-03-30
# 865   teenage mutant ninja turtles   2014-08-08
# 20                    the avengers   2012-05-04
# 21                    the avengers   1998-08-14
# 3087         the birth of a nation   2016-10-07
# 3089         the birth of a nation   1915-02-08
# 4052                   the calling   2009-12-31
# 4057                   the calling   2002-03-01
# 2197                   the gambler   2014-12-10
# 2198                   the gambler   1999-08-04
# 3152                      the gift   2000-12-19
# 3189                      the gift   2015-08-07
# 97                the great gatsby   1974-03-29
# 96                the great gatsby   2013-05-10
# 122                the jungle book   2016-04-15
# 124                the jungle book   1994-12-25
# 1580                the karate kid   1984-06-22
# 1579                the karate kid   2010-06-11
# 2791               the love letter   2015-08-18
# 2790               the love letter   1999-05-21
# 90                       the mummy   2017-06-09
# 91                       the mummy   1999-05-07
# 3820                    the signal   2008-02-22
# 3817                    the signal   2014-06-13
# 4250                    the square   2010-04-09
# 4259                    the square   2013-10-25
# 878                   total recall   1990-06-01
# 876                   total recall   2012-08-03
# 2712                        trance   2013-04-05
# 2716                        trance   2012-12-31
# 2633                 unforgettable   2017-04-21
# 2627                 unforgettable   1996-02-23
# 1605                       unknown   2011-02-18
# 1609                       unknown   2006-11-03
# 897                          venom   2018-10-05
# 902                          venom   2005-09-16

# %% [markdown]
# Note: The titles have different release_dates. I will assume that these are remakes.

# %%
#Add profit column = worldwide_gross - production_budget
final_df['profit'] = final_df['worldwide_gross'] - final_df['production_budget']
final_df['profit'].astype(int)
final_df.head()
# Out:
#      release_date                  title  production_budget  domestic_gross  \
# 4312   2015-11-20                #horror            1500000               0
# 3611   2016-03-11    10 cloverfield lane            5000000        72082999
# 3004   2015-11-11  10 days in a madhouse           12000000           14616
# 1761   2018-01-19              12 strong           35000000        45819713
# 2433   2013-10-18       12 years a slave           20000000        56671993
#
#       worldwide_gross original_language  popularity  vote_average  vote_count  \
# 4312                0                de       6.099           3.3         102
# 3611        108286422                en      17.892           6.9        4629
# 3004            14616                en       0.955           5.4           7
# 1761         71118378                en      13.183           5.6        1312
# 2433        181025343                en      16.493           7.9        6631
#
#       runtime_minutes       genres     profit
# 4312            101.0  cross-genre   -1500000
# 3611            103.0  cross-genre  103286422
# 3004            111.0        drama  -11985384
# 1761            130.0  cross-genre   36118378
# 2433            134.0  cross-genre  161025343

# %%
#Add release_date month column
final_df['release_month'] = pd.DatetimeIndex(final_df['release_date']).month
final_df.head()
# Out:
#      release_date                  title  production_budget  domestic_gross  \
# 4312   2015-11-20                #horror            1500000               0
# 3611   2016-03-11    10 cloverfield lane            5000000        72082999
# 3004   2015-11-11  10 days in a madhouse           12000000           14616
# 1761   2018-01-19              12 strong           35000000        45819713
# 2433   2013-10-18       12 years a slave           20000000        56671993
#
#       worldwide_gross original_language  popularity  vote_average  vote_count  \
# 4312                0                de       6.099           3.3         102
# 3611        108286422                en      17.892           6.9        4629
# 3004            14616                en       0.955           5.4           7
# 1761         71118378                en      13.183           5.6        1312
# 2433        181025343                en      16.493           7.9        6631
#
#       runtime_minutes       genres     profit  release_month
# 4312            101.0  cross-genre   -1500000             11
# 3611            103.0  cross-genre  103286422              3
# 3004            111.0        drama  -11985384             11
# 1761            130.0  cross-genre   36118378              1
# 2433            134.0  cross-genre  161025343             10

# %%
#Add release_date year column
final_df['release_year'] = pd.DatetimeIndex(final_df['release_date']).year
final_df.head()
# Out:
#      release_date                  title  production_budget  domestic_gross  \
# 4312   2015-11-20                #horror            1500000               0
# 3611   2016-03-11    10 cloverfield lane            5000000        72082999
# 3004   2015-11-11  10 days in a madhouse           12000000           14616
# 1761   2018-01-19              12 strong           35000000        45819713
# 2433   2013-10-18       12 years a slave           20000000        56671993
#
#       worldwide_gross original_language  popularity  vote_average  vote_count  \
# 4312                0                de       6.099           3.3         102
# 3611        108286422                en      17.892           6.9        4629
# 3004            14616                en       0.955           5.4           7
# 1761         71118378                en      13.183           5.6        1312
# 2433        181025343                en      16.493           7.9        6631
#
#       runtime_minutes       genres     profit  release_month  release_year
# 4312            101.0  cross-genre   -1500000             11          2015
# 3611            103.0  cross-genre  103286422              3          2016
# 3004            111.0        drama  -11985384             11          2015
# 1761            130.0  cross-genre   36118378              1          2018
# 2433            134.0  cross-genre  161025343             10          2013

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1879 entries, 4312 to 216
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   release_date       1879 non-null   datetime64[ns]
#  1   title              1879 non-null   object
#  2   production_budget  1879 non-null   int64
#  3   domestic_gross     1879 non-null   int64
#  4   worldwide_gross    1879 non-null   int64
#  5   original_language  1879 non-null   object
#  6   popularity         1879 non-null   float64
#  7   vote_average       1879 non-null   float64
#  8   vote_count         1879 non-null   int64
#  9   runtime_minutes    1879 non-null   float64
#  10  genres             1879 non-null   object
#  11  profit             1879 non-null   int64
#  12  release_month      1879 non-null   int64
#  13  release_year       1879 non-null   int64
# dtypes: datetime64[ns](1), float64(3), int64(7), object(3)
# memory usage: 220.2+ KB

# %% [markdown]
# # 6. Data Visualization

# %% [markdown]
# ### A. production_budget vs profit

# %%
final_df.describe()
# Out:
#        production_budget  domestic_gross  worldwide_gross   popularity  \
# count       1.879000e+03    1.879000e+03     1.879000e+03  1879.000000
# mean        3.857759e+07    4.866274e+07     1.199858e+08    11.014825
# std         5.227705e+07    8.027918e+07     2.227130e+08     8.272648
# min         9.000000e+03    0.000000e+00     0.000000e+00     0.600000
# 25%         5.000000e+06    1.020641e+06     3.413546e+06     6.193500
# 50%         2.000000e+07    2.053714e+07     3.802823e+07     9.620000
# 75%         4.700000e+07    5.814851e+07     1.236893e+08    14.476500
# max         4.250000e+08    7.605076e+08     2.776345e+09    80.773000
#
#        vote_average    vote_count  runtime_minutes        profit  \
# count   1879.000000   1879.000000      1879.000000  1.879000e+03
# mean       6.185045   1721.489090       103.420436  8.140817e+07
# std        1.088420   2710.819308        21.091007  1.835953e+08
# min        0.000000      1.000000         1.000000 -1.104502e+08
# 25%        5.600000     91.500000        92.000000 -1.512077e+06
# 50%        6.200000    673.000000       102.000000  1.394305e+07
# 75%        6.900000   2107.000000       115.000000  7.782303e+07
# max       10.000000  22186.000000       180.000000  2.351345e+09
#
#        release_month  release_year
# count    1879.000000   1879.000000
# mean        6.893560   2011.997871
# std         3.471833      7.624857
# min         1.000000   1915.000000
# 25%         4.000000   2011.000000
# 50%         7.000000   2013.000000
# 75%        10.000000   2015.000000
# max        12.000000   2019.000000

# %%
font = {'family': 'Times New Roman',
        'color':  'black',
        'weight': 'normal',
        'size': 16,
        }

fig, ax = plt.subplots(figsize = (10, 6))
x = final_df['production_budget']
y = final_df['profit']
ax.plot(x, y, 'o')

m, b = np.polyfit(x, y, 1)

ax.plot(x, m*x+b)
plt.xlabel('Budget ($)', fontdict=font)
plt.ylabel('Profit ($)', fontdict=font)
plt.title('Budget vs Profit', fontdict=font)

plt.style.use('ggplot')

plt.show()

#present as question: does profit impact profit?

# %%
#Correlation
final_df[['production_budget','profit']].corr()
# Out:
#                    production_budget    profit
# production_budget           1.000000  0.685621
# profit                      0.685621  1.000000

# %%
final_df.corr()
# Out:
#                    production_budget  domestic_gross  worldwide_gross  \
# production_budget           1.000000        0.731886         0.799926
# domestic_gross              0.731886        1.000000         0.945393
# worldwide_gross             0.799926        0.945393         1.000000
# popularity                  0.592447        0.590624         0.604237
# vote_average                0.146492        0.237473         0.222735
# vote_count                  0.639151        0.750139         0.753092
# runtime_minutes             0.321034        0.280054         0.291543
# profit                      0.685621        0.938425         0.985293
# release_month               0.004318        0.008232         0.016337
# release_year                0.094793        0.056586         0.081187
#
#                    popularity  vote_average  vote_count  runtime_minutes  \
# production_budget    0.592447      0.146492    0.639151         0.321034
# domestic_gross       0.590624      0.237473    0.750139         0.280054
# worldwide_gross      0.604237      0.222735    0.753092         0.291543
# popularity           1.000000      0.300556    0.720772         0.339194
# vote_average         0.300556      1.000000    0.340273         0.272482
# vote_count           0.720772      0.340273    1.000000         0.357499
# runtime_minutes      0.339194      0.272482    0.357499         1.000000
# profit               0.564285      0.228479    0.731557         0.262249
# release_month        0.033074      0.069246    0.039192         0.073151
# release_year         0.179417      0.081860    0.072418         0.095686
#
#                      profit  release_month  release_year
# production_budget  0.685621       0.004318      0.094793
# domestic_gross     0.938425       0.008232      0.056586
# worldwide_gross    0.985293       0.016337      0.081187
# popularity         0.564285       0.033074      0.179417
# vote_average       0.228479       0.069246      0.081860
# vote_count         0.731557       0.039192      0.072418
# runtime_minutes    0.262249       0.073151      0.095686
# profit             1.000000       0.018589      0.071494
# release_month      0.018589       1.000000     -0.018856
# release_year       0.071494      -0.018856      1.000000

# %% [markdown]
# Note: Larger budget = larger profit

# %%
#What are the production budgets of the top 10 most profitable movies?
most_profitable_df = final_df.sort_values(by=['profit'], ascending=False)
top_ten_profit_df = most_profitable_df[:10]
top_ten_profit_df
# Out:
#      release_date                           title  production_budget  \
# 0      2009-12-18                          avatar          425000000
# 3      2018-04-27          avengers: infinity war          300000000
# 26     2015-06-12                  jurassic world          215000000
# 93     2015-04-03                       furious 7          190000000
# 20     2012-05-04                    the avengers          225000000
# 60     2018-02-16                   black panther          200000000
# 154    2018-06-22  jurassic world: fallen kingdom          170000000
# 213    2013-11-22                          frozen          150000000
# 173    2017-03-17            beauty and the beast          160000000
# 1165   2015-07-10                         minions           74000000
#
#       domestic_gross  worldwide_gross original_language  popularity  \
# 0          760507625       2776345279                en      26.526
# 3          678815482       2048134200                en      80.773
# 26         652270625       1648854864                en      20.709
# 93         353007020       1518722794                en      20.396
# 20         623279547       1517935897                en      50.289
# 60         700059566       1348258224                en      44.140
# 154        417719760       1305772799                en      34.958
# 213        400738009       1272469910                en      26.183
# 173        504014165       1259199706                en      26.701
# 1165       336045770       1160336173                en       9.338
#
#       vote_average  vote_count  runtime_minutes       genres      profit  \
# 0              7.4       18676             93.0       horror  2351345279
# 3              8.3       13948            149.0  cross-genre  1748134200
# 26             6.6       14056            124.0  cross-genre  1433854864
# 93             7.3        6538            137.0  cross-genre  1328722794
# 20             7.6       19673            143.0  cross-genre  1292935897
# 60             7.4       12365            134.0  cross-genre  1148258224
# 154            6.5        5995            128.0  cross-genre  1135772799
# 213            7.3        9767             93.0  cross-genre  1122469910
# 173            7.7        5730            129.0  cross-genre  1099199706
# 1165           6.4        7343             91.0  cross-genre  1086336173
#
#       release_month  release_year
# 0                12          2009
# 3                 4          2018
# 26                6          2015
# 93                4          2015
# 20                5          2012
# 60                2          2018
# 154               6          2018
# 213              11          2013
# 173               3          2017
# 1165              7          2015

# %%
fig, ax = plt.subplots(figsize=(16,8))

x = top_ten_profit_df['title']
y = top_ten_profit_df['production_budget']

ax.bar(x,y)

ax.set_xlabel('Title', fontdict=font)
ax.set_ylabel('Budget', fontdict=font)
ax.set_title('Production Budget of Top 10 Most Profitable Movies', fontdict=font)

plt.xticks(x, rotation=60);

plt.axhline(final_df['production_budget'].mean(), color='black', label='overall avg budget');
plt.legend();

#update scientific notation

# %% [markdown]
# ### B. genres vs profit

# %%
#Look into dataset of each genre
genres_df = final_df.groupby('genres')
genres_df.size()
# Out:
# genres
# action            6
# adventure         1
# animation         4
# biography         3
# comedy           69
# cross-genre    1551
# documentary      67
# drama           109
# family            4
# fantasy           4
# horror           38
# musical           2
# mystery           2
# romance           2
# sci-fi            3
# thriller         13
# western           1
# dtype: int64

# %% [markdown]
# Note: There is not enough data on specific genres to analyze.

# %% [markdown]
# ### B. release_month vs profit

# %%
#Look at all genres and mean of profits
month_profit_df = final_df[['release_month', 'profit']]
mean_month_profit_df = month_profit_df.groupby('release_month').mean()
mean_month_profit_df
# Out:
#                      profit
# release_month
# 1              4.014091e+07
# 2              6.624628e+07
# 3              7.023648e+07
# 4              7.136186e+07
# 5              1.322796e+08
# 6              1.478909e+08
# 7              1.173484e+08
# 8              4.651537e+07
# 9              3.642184e+07
# 10             4.659402e+07
# 11             1.211263e+08
# 12             8.893125e+07

# %%
#Determine if there is enough data by month to analyze = YES!
profit_df = final_df.groupby('release_month')
profit_df.size()
# Out:
# release_month
# 1     117
# 2     140
# 3     166
# 4     152
# 5     127
# 6     150
# 7     150
# 8     159
# 9     166
# 10    183
# 11    159
# 12    210
# dtype: int64

# %%
font = {'family': 'Times New Roman',
        'color':  'black',
        'weight': 'normal',
        'size': 16,
        }

plot = mean_month_profit_df.plot(kind='bar', figsize=(12,8), legend=False)

plt.xlabel('Release Month', fontdict=font)
plt.ylabel('Avg Profit ($)', fontdict=font)
plt.title('Release Month vs Avg Profit', fontdict=font)

plt.axhline(mean_month_profit_df['profit'].mean(), color='black');

plt.style.use('ggplot')

#look into movies release by month numbers in observation (competition by month)

# %% [markdown]
# ### D. vote_average vs production_budget

# %%
font = {'family': 'Times New Roman',
        'color':  'black',
        'weight': 'normal',
        'size': 16,
        }

fig, ax = plt.subplots(figsize = (12, 8))
x = final_df['vote_average']
y = final_df['production_budget']
ax.plot(x, y, 'o')

m, b = np.polyfit(x, y, 1)

ax.plot(x, m*x+b)
plt.xlabel('Rating', fontdict=font)
plt.ylabel('Budget ($)', fontdict=font)
plt.title('Rating vs Budget', fontdict=font)

plt.style.use('ggplot')

plt.show()

#Flip to budget(x) vs rating(y)

# %% [markdown]
# Note: Bigger budget = higher rating. However, there is a lot of datapoints clumped at around Rating 6 with smaller budget films. I do not want to encourage low-budget film making for Microsoft.

# %%
#Look into vote_count
final_df['vote_count'].describe()
# Out:
# count     1879.000000
# mean      1721.489090
# std       2710.819308
# min          1.000000
# 25%         91.500000
# 50%        673.000000
# 75%       2107.000000
# max      22186.000000
# Name: vote_count, dtype: float64

# %%
font = {'family': 'Times New Roman',
        'color':  'black',
        'weight': 'normal',
        'size': 16,
        }

fig, ax = plt.subplots(figsize = (12, 8))
x = final_df['vote_average']
y = final_df['vote_count']
ax.plot(x, y, 'o')

m, b = np.polyfit(x, y, 1)

ax.plot(x, m*x+b)
plt.xlabel('Rating', fontdict=font)
plt.ylabel('Vote Count', fontdict=font)
plt.title('Rating vs Vote Count', fontdict=font)

plt.style.use('ggplot')

plt.show()

# %% [markdown]
# Note: Looks very similar to Rating vs Budget

# %%
#Set min vote_count >= 700
new_vote_df = final_df[['vote_average', 'production_budget', 'vote_count']]
min_vote_df = new_vote_df[new_vote_df['vote_count'] >= 700]
min_vote_df.describe()
# Out:
#        vote_average  production_budget    vote_count
# count    917.000000       9.170000e+02    917.000000
# mean       6.495747       6.279150e+07   3328.918212
# std        0.751878       6.295456e+07   3157.398056
# min        4.000000       1.000000e+05    700.000000
# 25%        6.000000       1.900000e+07   1246.000000
# 50%        6.500000       4.000000e+07   2153.000000
# 75%        7.100000       9.000000e+07   4124.000000
# max        8.300000       4.250000e+08  22186.000000

# %%
font = {'family': 'Times New Roman',
        'color':  'black',
        'weight': 'normal',
        'size': 16,
        }

fig, ax = plt.subplots(figsize = (12, 8))
x = min_vote_df['vote_average']
y = min_vote_df['production_budget']
ax.plot(x, y, 'o')

m, b = np.polyfit(x, y, 1)

ax.plot(x, m*x+b)
plt.xlabel('Rating', fontdict=font)
plt.ylabel('Budget ($)', fontdict=font)
plt.title('Rating vs Budget', fontdict=font)
plt.show()

plt.style.use('ggplot')

# %% [markdown]
# Note: Still a lot of noise. However rating range has been updated to 4-9.

# %%
#Group by Rating using a bar plot
#First, roundup vote_average
min_vote_df['vote_average'] = min_vote_df['vote_average'].round(decimals=0)
# Out:
# <ipython-input-175-eab069e28ee2>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   min_vote_df['vote_average'] = min_vote_df['vote_average'].round(decimals=0)

# %%
min_vote_df.head()
# Out:
#       vote_average  production_budget  vote_count
# 3611           7.0            5000000        4629
# 1761           6.0           35000000        1312
# 2433           8.0           20000000        6631
# 2609           7.0           18000000        4469
# 1261           6.0           61000000        2368

# %%
min_vote_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 917 entries, 3611 to 216
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   vote_average       917 non-null    float64
#  1   production_budget  917 non-null    int64
#  2   vote_count         917 non-null    int64
# dtypes: float64(1), int64(2)
# memory usage: 28.7 KB

# %%
grouped_vote_df = min_vote_df.groupby('vote_average')
grouped_vote_df.size()
# Out:
# vote_average
# 4.0      8
# 5.0     61
# 6.0    416
# 7.0    341
# 8.0     91
# dtype: int64

# %%
#Groupby vote_average
grouped_vote_average_df = min_vote_df.groupby('vote_average', as_index=False).mean()
grouped_vote_average_df
# Out:
#    vote_average  production_budget   vote_count
# 0           4.0       5.137500e+07  1634.125000
# 1           5.0       5.288525e+07  1685.262295
# 2           6.0       6.402350e+07  2423.134615
# 3           7.0       6.104760e+07  3828.445748
# 4           8.0       7.133846e+07  6848.571429

# %%
fig, ax = plt.subplots(figsize = (12, 8))
x = grouped_vote_average_df ['vote_average']
y = grouped_vote_average_df ['production_budget']/1000000
ax.bar(x, y)

ax.set_xlabel('Rating', fontdict=font)
ax.set_ylabel('Avg Budget ($ millions)', fontdict=font)
ax.set_title('Rating vs Budget', fontdict=font)
plt.show()

# %% [markdown]
# Note: For a rating of 6 and higher, set budget at around $60,000,000

# %% [markdown]
# ### E. runtime_minutes vs profit

# %%
font = {'family': 'Times New Roman',
        'color':  'black',
        'weight': 'normal',
        'size': 16,
        }

fig, ax = plt.subplots(figsize = (12, 8))
x = final_df['runtime_minutes']
y = final_df['profit']
ax.plot(x, y, 'o')

m, b = np.polyfit(x, y, 1)

ax.plot(x, m*x+b)
plt.xlabel('Runtime (min)', fontdict=font)
plt.ylabel('Profit ($)', fontdict=font)
plt.title('Scatter Plot of Runtime vs Profit', fontdict=font)
plt.show()

#rerun after adding updated df (avatar)

# %% [markdown]
# Note: Aim for 100-150 minutes for a higher profit margin

# %%
#Issue with avatar runtime and genre. Upon further investigation online, there is a another movie of the same name. How should I go about cleaning this up?
final_df[final_df['title'].str.contains('avatar')]
# Out:
#   release_date   title  production_budget  domestic_gross  worldwide_gross  \
# 0   2009-12-18  avatar          425000000       760507625       2776345279
#
#   original_language  popularity  vote_average  vote_count  runtime_minutes  \
# 0                en      26.526           7.4       18676             93.0
#
#    genres      profit  release_month  release_year
# 0  horror  2351345279             12          2009

# %%
#According to IMBD, genre = action, adventure, fantasy (cross-genre)
final_df.loc[final_df['title'] == 'avatar', 'genres'] = 'cross_genre'

# %%
final_df[final_df['title'].str.contains('avatar')]
# Out:
#   release_date   title  production_budget  domestic_gross  worldwide_gross  \
# 0   2009-12-18  avatar          425000000       760507625       2776345279
#
#   original_language  popularity  vote_average  vote_count  runtime_minutes  \
# 0                en      26.526           7.4       18676             93.0
#
#         genres      profit  release_month  release_year
# 0  cross_genre  2351345279             12          2009

# %%
#According to IMBD, runtime = 162 min
final_df.loc[final_df['title'] == 'avatar', 'runtime_minutes'] = 162

# %%
final_df[final_df['title'].str.contains('avatar')]
# Out:
#   release_date   title  production_budget  domestic_gross  worldwide_gross  \
# 0   2009-12-18  avatar          425000000       760507625       2776345279
#
#   original_language  popularity  vote_average  vote_count  runtime_minutes  \
# 0                en      26.526           7.4       18676            162.0
#
#         genres      profit  release_month  release_year
# 0  cross_genre  2351345279             12          2009

# %%
#Double check final_df
final_df.head()
# Out:
#      release_date                  title  production_budget  domestic_gross  \
# 4312   2015-11-20                #horror            1500000               0
# 3611   2016-03-11    10 cloverfield lane            5000000        72082999
# 3004   2015-11-11  10 days in a madhouse           12000000           14616
# 1761   2018-01-19              12 strong           35000000        45819713
# 2433   2013-10-18       12 years a slave           20000000        56671993
#
#       worldwide_gross original_language  popularity  vote_average  vote_count  \
# 4312                0                de       6.099           3.3         102
# 3611        108286422                en      17.892           6.9        4629
# 3004            14616                en       0.955           5.4           7
# 1761         71118378                en      13.183           5.6        1312
# 2433        181025343                en      16.493           7.9        6631
#
#       runtime_minutes       genres     profit  release_month  release_year
# 4312            101.0  cross-genre   -1500000             11          2015
# 3611            103.0  cross-genre  103286422              3          2016
# 3004            111.0        drama  -11985384             11          2015
# 1761            130.0  cross-genre   36118378              1          2018
# 2433            134.0  cross-genre  161025343             10          2013

# %%
#Double check final_df
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1879 entries, 4312 to 216
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   release_date       1879 non-null   datetime64[ns]
#  1   title              1879 non-null   object
#  2   production_budget  1879 non-null   int64
#  3   domestic_gross     1879 non-null   int64
#  4   worldwide_gross    1879 non-null   int64
#  5   original_language  1879 non-null   object
#  6   popularity         1879 non-null   float64
#  7   vote_average       1879 non-null   float64
#  8   vote_count         1879 non-null   int64
#  9   runtime_minutes    1879 non-null   float64
#  10  genres             1879 non-null   object
#  11  profit             1879 non-null   int64
#  12  release_month      1879 non-null   int64
#  13  release_year       1879 non-null   int64
# dtypes: datetime64[ns](1), float64(3), int64(7), object(3)
# memory usage: 220.2+ KB

# %% [markdown]
# # Scraping test

# %%
#Let's try to bring in another data set with avatar in it
#Existing csv's do not have correct runtime or genre for avatar
#Let's scrape data for avatar (https://www.rottentomatoes.com/m/avatar)

# %%
#from bs4 import BeautifulSoup
#mport requests

# %%
#url = "https://www.rottentomatoes.com/m/avatar"
#html_page = requests.get(url)
#soup = BeautifulSoup(html_page.content, 'html.parser')

# %%
#Scrape for genre
#genre_data = []

#for x in soup.find_all("div", class_="meta-value genre"):
#   genre_data = x.text

# %%
#genre_data

# %%
#genre_data = genre_data.replace('\n', '')

# %%
#genre_data = genre_data.replace(' ', '')

# %%
#genre_data
